# %% [markdown]
# # Predicción del score de la review
#
# A) ¿Qué tan difícil es predecir el score de la review?
#
# B) ¿Cuál es el modelo más sencillo que puede construirse con resultados aceptables?
#
# C) ¿Cuál es la menor cantidad de datos que puede usarse para tener datos aceptables?

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ## Importo librerias

# %%
import pandas as pd
import numpy as np
import datetime as dt
from matplotlib import pyplot as plt

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %% [markdown]
# ## Leo datasets

# %%
df_reviews = pd.read_csv("dataset/silkroad_reviews.csv")
df_items = pd.read_csv("dataset/silkroad_items.csv")
df_shippings = pd.read_csv("dataset/silkroad_shippings.csv")

# %% [markdown]
# # Exploracion

# %% [markdown]
# ### Analisis del target

# %% [markdown]
# Observo que mi target se encuentra en el dataset silkroad_reviews.csv en la columna rating.

# %%
df_reviews.head()
# Out:
#                                   item_id date_created  \
# 0                    250-grams-ghb-powder   2013-11-28
# 1            10g-washed-fishscale-cocaine   2013-11-28
# 2                       roche-valium-10mg   2013-11-28
# 3            10g-washed-fishscale-cocaine   2013-11-28
# 4  influence-the-psychology-of-persuasion   2013-11-28
#
#                                              comment  rating
# 0                       fast shipping, great product     5.0
# 1  Amazing product!  Perfect stealth.    Will def...     5.0
# 2  good vendor, posted express when paid for regu...     5.0
# 3                                        great stuff     5.0
# 4  Item received as advertised. Quick response. G...     5.0

# %%
df_reviews["rating"].value_counts()
# Out:
# 5.0       297369
# 0.0        16837
# 50.0           1
# 1335.0         1
# 500.0          1
# Name: rating, dtype: int64

# %% [markdown]
# Se observa que la mayoria de los valores de rating son 0 o 5. Por lo tanto, se considera valores distintos a 0 como outliers.
#
# Ademas, como hay solo dos posibles clasificaciones, se considerara como un problema binario y encondeamos de acuerdo.

# %%
df_reviews["rating"].astype(int)
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 314204    0
# 314205    5
# 314206    5
# 314207    5
# 314208    5
# Name: rating, Length: 314209, dtype: int64

# %%
def encode_target(df, column_name="rating"):
    df[column_name] = df[column_name]
    df[column_name] = df[column_name].apply(lambda x: x if(x==5.0 or x==0.0) else np.nan)
    df[column_name] = df[column_name].replace(5.0, 1.0)
    df = df.dropna(subset=[column_name])
    return df

# %% [markdown]
# ## Fetures selection

# %% [markdown]
# Se va acrear un dataframe general donde se encontraran los features que se utilizaran para predecir lo buscado.

# %%
df_general = df_reviews.copy()
df_general = encode_target(df_reviews)
df_general.head()
# Out:
#                                   item_id date_created  \
# 0                    250-grams-ghb-powder   2013-11-28
# 1            10g-washed-fishscale-cocaine   2013-11-28
# 2                       roche-valium-10mg   2013-11-28
# 3            10g-washed-fishscale-cocaine   2013-11-28
# 4  influence-the-psychology-of-persuasion   2013-11-28
#
#                                              comment  rating
# 0                       fast shipping, great product     1.0
# 1  Amazing product!  Perfect stealth.    Will def...     1.0
# 2  good vendor, posted express when paid for regu...     1.0
# 3                                        great stuff     1.0
# 4  Item received as advertised. Quick response. G...     1.0

# %% [markdown]
# ### Analisis dataset items.csv y shipping.csv

# %% [markdown]
# Ante la inmanejable cantidad de columnas duplicadas al generar un mergeo de este dataset con aquel en el que se encuentra el target, se opta por generar features a partir del id_del item para mergear con el general.
#
# Para features:
# - numericos: creo promedio, maximo, minimo, desviacion standard
# - fecha: maximos dias consecutivos, cantidad por dia, por ano, por mes.
# - categoricos: concatenacion

# %%
df_shippings.head()
# Out:
#                                              item_id  \
# 0                             jj-luna-privacy-ebooks
# 1                         the-morality-of-capitalism
# 2                                            survive
# 3                      a-non-religious-new-testament
# 4  mindless-slogans-101-cheap-substitutes-for-act...
#
#                     description est_delivery     price            timestamp
# 0                    ebook link        1 day  0.000000  2014-02-23T05:39:22
# 1                        letter       4 days  0.001722  2014-02-23T05:39:29
# 2         small book (domestic)       4 days  0.017217  2014-02-23T05:39:33
# 3  media mail parcel (domestic)       4 days  0.006870  2014-02-23T05:39:37
# 4                    ebook link        1 day  0.000000  2014-02-23T05:39:41

# %%
def features_items(df_items):

    df_items_to_merge = pd.DataFrame()
    
    df_items_group_by_price = df_items.groupby("item_id")["price"]
    df_items_to_merge["CF|item|price_mean"] = .mean()
    df_items_to_merge["CF|item|price_quantile50"] = df_items_group_by_price.quantile(0.5)
    df_items_to_merge["CF|item|price_quantile75"] = df_items_group_by_price.quantile(0.75)
    df_items_to_merge["CF|item|price_quantile25"] = df_items_group_by_price.quantile(0.25)
    df_items_to_merge["CF|item|price_count"] = df_items_group_by_price.count()
    df_items_to_merge["CF|item|price_max"] = df_items_group_by_price.max()
    df_items_to_merge["CF|item|price_min"] = df_items_group_by_price.min()
    df_items_to_merge["CF|item|price_std"] = df_items_group_by_price.std()

    df_items_to_merge["CF|item|original_path"] = df_items.groupby("item_id")["original_path"].apply(lambda x: ' '.join(x))

    df_items_to_merge["CF|item|vendor"] = df_items.groupby("item_id")["vendor"].apply(lambda x: ' '.join(x))

    df_items_to_merge["CF|item|title"] = df_items.groupby("item_id")["title"].apply(lambda x: ' '.join(x))

    df_items_to_merge["CF|item|category"] = df_items.groupby("item_id")["category"].apply(lambda x: ' '.join(x))
    
    return df_items_to_merge.reset_index()

# %%
df_items_to_merge = features_items(df_items)
df_items_to_merge.head()
# Out:
#                                              item_id  CF|item|price_mean  \
# 0  0-001g-10g-lcd-digital-jewelry-diamond-pocket-...            0.084408
# 1  0-001g-20g-precision-measure-digital-milligram...            0.051429
# 2  0-01g-precision-scale-pocketsize-small-and-com...            0.105000
# 3      0-1-gr-ketamine-sample-only-one-sample-person            0.000000
# 4   0-1-gram-quality-ice-shard-express-post-shipping            0.213443
#
#    CF|item|price_max  CF|item|price_min  CF|item|price_std  \
# 0           0.092069           0.076747           0.010834
# 1           0.051429           0.051429                NaN
# 2           0.105000           0.105000                NaN
# 3           0.000000           0.000000                NaN
# 4           0.261040           0.174321           0.026630
#
#                                CF|item|original_path  \
# 0  2014-03-03/items/0-001g-10g-lcd-digital-jewelr...
# 1  2014-02-11/items/0-001g-20g-precision-measure-...
# 2  2014-10-15/items/0-01g-precision-scale-pockets...
# 3  2014-09-26/items/0-1-gr-ketamine-sample-only-o...
# 4  2014-08-27/items/0-1-gram-quality-ice-shard-ex...
#
#                                       CF|item|vendor  \
# 0                                sweshroom sweshroom
# 1                                          sweshroom
# 2                                              sn4pp
# 3                                           SRvendor
# 4  Twokeen Twokeen Twokeen Twokeen Twokeen Twokee...
#
#                                        CF|item|title  \
# 0  0.001g-10g LCD Digital Jewelry Diamond Pocket ...
# 1  0.001g 20g precision measure Digital Milligram...
# 2  0.01g Precision scale - Pocketsize (Small and ...
# 3  0.1 gr Ketamine Sample - ONLY one sample / PERSON
# 4  0.1 gram Quality Ice Shard Express Post Shippi...
#
#                                     CF|item|category
# 0              Drug paraphernalia Drug paraphernalia
# 1                                 Drug paraphernalia
# 2                                            Alcohol
# 3                                      Dissociatives
# 4  Stimulants Stimulants Stimulants Stimulants St...

# %%
def encode_est_delivery(x):
    if (x == "contact vendor"):
        return -1
    return int(x.split(" ")[0])
    
df_shippings["CF|est_delivery"] = df_shippings["est_delivery"].astype(str).apply(lambda x: encode_est_delivery(x))

# %%
def features_items(df_shippings):

    df_shippings_to_merge = pd.DataFrame()

    df_shippings_to_merge["CF|shippings|price_mean"] = df_shippings.groupby("item_id")["price"].mean()
    df_shippings_to_merge["CF|shippings|price_max"] = df_shippings.groupby("item_id")["price"].max()
    df_shippings_to_merge["CF|shippings|price_min"] = df_shippings.groupby("item_id")["price"].min()
    df_shippings_to_merge["CF|shippings|price_std"] = df_shippings.groupby("item_id")["price"].std()
    df_shippings_to_merge["CF|shippings|price_std"] = df_shippings.groupby("item_id")["price"].std()

    df_shippings_to_merge["CF|shippings|est_delivery_mean"] = df_shippings.groupby("item_id")["CF|est_delivery"].mean()
    df_shippings_to_merge["CF|shippings|est_delivery_max"] = df_shippings.groupby("item_id")["CF|est_delivery"].max()
    df_shippings_to_merge["CF|shippings|est_delivery_min"] = df_shippings.groupby("item_id")["CF|est_delivery"].min()
    df_shippings_to_merge["CF|shippings|est_delivery_std"] = df_shippings.groupby("item_id")["CF|est_delivery"].std()

    df_shippings["description"] = df_shippings["description"].astype(str)
    df_shippings_to_merge["CF|shippings|description"] = df_shippings.groupby("item_id")["description"].apply(lambda x: ' '.join(x))
    
    return df_shippings_to_merge.reset_index()

# %%
df_shippings_to_merge = features_items(df_shippings)
df_shippings_to_merge.head()
# Out:
#                                              item_id  CF|shippings|price_mean  \
# 0  0-001g-10g-lcd-digital-jewelry-diamond-pocket-...                 0.009397
# 1  0-001g-20g-precision-measure-digital-milligram...                 0.006327
# 2  0-01g-precision-scale-pocketsize-small-and-com...                 0.000000
# 3      0-1-gr-ketamine-sample-only-one-sample-person                 0.025629
# 4   0-1-gram-quality-ice-shard-express-post-shipping                 0.024029
#
#    CF|shippings|price_max  CF|shippings|price_min  CF|shippings|price_std  \
# 0                0.017267                0.000000                0.005732
# 1                0.012180                0.000000                0.005139
# 2                0.000000                0.000000                     NaN
# 3                0.025629                0.025629                0.000000
# 4                0.029741                0.018636                0.003493
#
#    CF|shippings|est_delivery_mean  CF|shippings|est_delivery_max  \
# 0                        6.285714                             14
# 1                        7.250000                             14
# 2                        1.000000                              1
# 3                        7.000000                              7
# 4                        2.000000                              2
#
#    CF|shippings|est_delivery_min  CF|shippings|est_delivery_std  \
# 0                              2                       4.498677
# 1                              2                       5.377422
# 2                              1                            NaN
# 3                              7                       0.000000
# 4                              2                       0.000000
#
#                             CF|shippings|description
# 0  Europe Worldwide Domestic (Sweden) Add Items t...
# 1  Add Items to a order you are about to place wi...
# 2                                      Free shipping
# 3  FREE 0.1 gr Cocaine Sample - ONLY one sample /...
# 4  Express Post Shipping Express Post Shipping Ex...

# %%
df_general = df_general.merge(df_items_to_merge, how="left", on="item_id").merge(df_shippings_to_merge, how="left", on="item_id")

# %%
df_general.head()
# Out:
#                                   item_id date_created  \
# 0                    250-grams-ghb-powder   2013-11-28
# 1            10g-washed-fishscale-cocaine   2013-11-28
# 2                       roche-valium-10mg   2013-11-28
# 3            10g-washed-fishscale-cocaine   2013-11-28
# 4  influence-the-psychology-of-persuasion   2013-11-28
#
#                                              comment  rating  \
# 0                       fast shipping, great product     1.0
# 1  Amazing product!  Perfect stealth.    Will def...     1.0
# 2  good vendor, posted express when paid for regu...     1.0
# 3                                        great stuff     1.0
# 4  Item received as advertised. Quick response. G...     1.0
#
#    CF|item|price_mean  CF|item|price_max  CF|item|price_min  \
# 0            0.762496           1.214565           0.436762
# 1            0.019282           0.029080           0.012058
# 2            0.008892           0.011954           0.006670
# 3            0.019282           0.029080           0.012058
# 4            0.002099           0.003146           0.001343
#
#    CF|item|price_std                              CF|item|original_path  \
# 0           0.182588  2013-12-20/items/250-grams-ghb-powder 2014-01-...
# 1           0.004771  2014-02-24/items/10g-washed-fishscale-cocaine_...
# 2           0.001381  2014-02-24/items/roche-valium-10mg 2013-12-20/...
# 3           0.004771  2014-02-24/items/10g-washed-fishscale-cocaine_...
# 4           0.000458  2014-02-24/items/influence-the-psychology-of-p...
#
#                                       CF|item|vendor  ...  \
# 0  HoneyBee HoneyBee HoneyBee HoneyBee HoneyBee H...  ...
# 1  bcpltd bcpltd bcpltd bcpltd bcpltd bcpltd bcpl...  ...
# 2  thetransporter thetransporter thetransporter t...  ...
# 3  bcpltd bcpltd bcpltd bcpltd bcpltd bcpltd bcpl...  ...
# 4  MrTerrific MrTerrific MrTerrific MrTerrific Mr...  ...
#
#                                     CF|item|category CF|shippings|price_mean  \
# 0  GHB GHB GHB GHB GHB GHB GHB GHB GHB GHB GHB Dr...                 0.01420
# 1  Stimulants Stimulants Stimulants Stimulants St...                 0.00000
# 2  Prescription Prescription Prescription Prescri...                 0.01485
# 3  Stimulants Stimulants Stimulants Stimulants St...                 0.00000
# 4  Alcohol Alcohol Alcohol Alcohol Alcohol Alcoho...                 0.00000
#
#    CF|shippings|price_max  CF|shippings|price_min  CF|shippings|price_std  \
# 0                0.022239                0.008277                0.003453
# 1                0.000000                0.000000                     NaN
# 2                0.034821                0.002988                0.011156
# 3                0.000000                0.000000                     NaN
# 4                0.000000                0.000000                     NaN
#
#    CF|shippings|est_delivery_mean  CF|shippings|est_delivery_max  \
# 0                        4.000000                              4
# 1                        5.000000                              5
# 2                        4.942857                              7
# 3                        5.000000                              5
# 4                        1.000000                              1
#
#    CF|shippings|est_delivery_min  CF|shippings|est_delivery_std  \
# 0                              4                        0.00000
# 1                              5                            NaN
# 2                              3                        2.02837
# 3                              5                            NaN
# 4                              1                            NaN
#
#                             CF|shippings|description
# 0  USPS USPS USPS USPS USPS USPS USPS USPS USPS U...
# 1                                      Free Shipping
# 2  Regular Express  Express  Regular Express  Reg...
# 3                                      Free Shipping
# 4                                   Digital Download
#
# [5 rows x 21 columns]

# %% [markdown]
# # Exploracion de datos

# %%
def describe_categorical_features(df):
    categorical_features = df.columns[df.dtypes == object]
    for feature in categorical_features:
        print(feature + "---------------------------")
        print(df[feature].value_counts())
        print()

# %%
df_reviews.head()
# Out:
#                                   item_id date_created  \
# 0                    250-grams-ghb-powder   2013-11-28
# 1            10g-washed-fishscale-cocaine   2013-11-28
# 2                       roche-valium-10mg   2013-11-28
# 3            10g-washed-fishscale-cocaine   2013-11-28
# 4  influence-the-psychology-of-persuasion   2013-11-28
#
#                                              comment  rating
# 0                       fast shipping, great product     5.0
# 1  Amazing product!  Perfect stealth.    Will def...     5.0
# 2  good vendor, posted express when paid for regu...     5.0
# 3                                        great stuff     5.0
# 4  Item received as advertised. Quick response. G...     5.0

# %%
describe_categorical_features(df_reviews)
# Out:
# item_id---------------------------
# 5g-white-widow-dutchmagic                                                                                   1464
# ketamine-1g-c64897dc-9ab4-43e6-8d93-a9e38dccc8e4                                                            1189
# liquid-mushrooms-pure-psilocybin-no-nausea-faster-trip-cleaner-feel-than-dried-shrooms-click-for-details    1118
# 1-0-gram-pure-columbian-flake-high-quality-cocaine-meerkovo                                                 1022
# 1g-platinum-standard-pure-fire-mdma                                                                          993
#                                                                                                             ...
# 3-lsd-blotters-110-g-apningstilbud                                                                             1
# 10g-northern-lights-a-coffeshop-quality-weed                                                                   1
# 10-x-mdma-capsules-125mg-90-2-new-vendor-special-200-with-free-shipping                                        1
# p-cubensis-pes-hawaiian-dried-whole-pieces-20-0-g-goblin                                                       1
# limited-time-sale-strawberry-kush-strain-3-5-grams                                                             1
# Name: item_id, Length: 12749, dtype: int64
#
# date_created---------------------------
# 2014-09-13    2266
# 2014-10-21    2029
# 2014-10-15    1876
# 2014-10-16    1862
# 2014-10-22    1860
#               ...
# 2013-11-30     104
# 2013-12-01      55
# 2013-12-24       8
# 2013-12-28       5
# 2013-12-26       1
# Name: date_created, Length: 335, dtype: int64
#
# comment---------------------------
# 5/5                                                                                                                                                                                   1222
# good                                                                                                                                                                                   898
# A+                                                                                                                                                                                     861
# perfect                                                                                                                                                                                745
# great                                                                                                                                                                                  723
#                                                                                                                                                                                       ...
# got pills as scheduled great vender will be back!!                                                                                                                                       1
# Item received.  Will have blood test results back in a few days to see if its legit                                                                                                      1
# very reliable vendor. gave me great stuff. sorry i took a while to finalize. it shipped fast, but the road went down :(. this guys great                                                 1
# Good-ish stuff, great speed, great stealth!                                                                                                                                              1
# 100% trustworthy vendor. Thanks ThreeKings, was sceptical on ordering, but came proffessionaly packaged and in very quick time to a far hard destination. 100% trustworthy vendor.       1
# Name: comment, Length: 251711, dtype: int64

# %%
lm = WordNetLemmatizer()
def text_transformation(df_col):
    corpus = []
    for item in df_col:
        new_item = re.sub('[^a-zA-Z]',' ',str(item))
        new_item = new_item.lower()
        new_item = new_item.split()
        new_item = [lm.lemmatize(word) for word in new_item if word not in set(stopwords.words('english'))]
        corpus.append(' '.join(str(x) for x in new_item))
    return corpus

# %%
corpus = text_transformation(df_reviews['comment'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3a0abe8a2015> in <module>
# ----> 1 corpus = text_transformation(df_reviews['comment'])
#
# <ipython-input-16-56b8bb8f7cbc> in text_transformation(df_col)
#       6         new_item = new_item.lower()
#       7         new_item = new_item.split()
# ----> 8         new_item = [lm.lemmatize(word) for word in new_item if word not in set(stopwords.words('english'))]
#       9         corpus.append(' '.join(str(x) for x in new_item))
#      10     return corpus
#
# <ipython-input-16-56b8bb8f7cbc> in <listcomp>(.0)
#       6         new_item = new_item.lower()
#       7         new_item = new_item.split()
# ----> 8         new_item = [lm.lemmatize(word) for word in new_item if word not in set(stopwords.words('english'))]
#       9         corpus.append(' '.join(str(x) for x in new_item))
#      10     return corpus
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      21         return [
#      22             line
# ---> 23             for line in line_tokenize(self.raw(fileids))
#      24             if not line.startswith(ignore_lines_startswith)
#      25         ]
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/corpus/reader/wordlist.py in raw(self, fileids)
#      30         elif isinstance(fileids, str):
#      31             fileids = [fileids]
# ---> 32         return concat([self.open(f).read() for f in fileids])
#      33
#      34
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/corpus/reader/wordlist.py in <listcomp>(.0)
#      30         elif isinstance(fileids, str):
#      31             fileids = [fileids]
# ---> 32         return concat([self.open(f).read() for f in fileids])
#      33
#      34
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/corpus/reader/api.py in open(self, file)
#     206         """
#     207         encoding = self.encoding(file)
# --> 208         stream = self._root.join(file).open(encoding)
#     209         return stream
#     210
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/data.py in open(self, encoding)
#     325         stream = open(self._path, "rb")
#     326         if encoding is not None:
# --> 327             stream = SeekableUnicodeStreamReader(stream, encoding)
#     328         return stream
#     329
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/compat.py in _decorator(*args, **kwargs)
#      39     def _decorator(*args, **kwargs):
#      40         args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41         return init_func(*args, **kwargs)
#      42
#      43     return wraps(init_func)(_decorator)
#
# /opt/anaconda3/lib/python3.8/site-packages/nltk/data.py in __init__(self, stream, encoding, errors)
#    1002            'replace'."""
#    1003
# -> 1004         self.decode = codecs.getdecoder(encoding)
#    1005         """The function that is used to decode byte strings into
#    1006            unicode strings."""
#
# /opt/anaconda3/lib/python3.8/codecs.py in getdecoder(encoding)
#     973
#     974     """
# --> 975     return lookup(encoding).decode
#     976
#     977 def getincrementalencoder(encoding):
#
# KeyboardInterrupt:

# %%
df_reviews["NF|npl"] = corpus

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidf_encoding(df, feature_name, prefix, min_df=0.01, df_test= None, isTest = False):
    train = df[feature_name].fillna("")
    tfidfvectorizer = TfidfVectorizer(analyzer='word',stop_words= 'english', min_df=min_df)
    tfidf_wm = tfidfvectorizer.fit_transform(train)
    tfidf_tokens = tfidfvectorizer.get_feature_names()
    if(isTest):
        test = df_test[feature_name].fillna("")
        tfidf_wm = tfidfvectorizer.transform(test)
    df_tfidfvect = pd.DataFrame(data = tfidf_wm.toarray(), columns = tfidf_tokens)
    df_tfidfvect.columns = ["NF|TFIDF|" + prefix + "|" + x for x in df_tfidfvect.columns]
    return df_tfidfvect

# %%
df_review_tfidf = tfidf_encoding(df_reviews, "NF|npl", "comment", min_df=0.01, df_test= None, isTest = False)

# %%
df_review_tfidf

# %%
# FEATURE: est_delivery

def encode_est_delivery(x):
    if (x == "contact vendor"):
        return -1
    return int(x.split(" ")[0])
    

df_reviews["CUSTOM_est_delivery"] = df_reviews["est_delivery"].astype(str).apply(lambda x: encode_est_delivery(x))
